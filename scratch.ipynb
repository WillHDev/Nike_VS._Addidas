# %%
model_1_vars = [
    # Depression outcome
    "happy",     
    "life",
    "health",
    "goodlife",
    # Education
    "educ",          
    "anomia7", 
    #"anomia8", "anomia9",
    
    # Religiosity (components or composite inputs)
    "attend",
    "pray",
    "reliten",
    
    # Core controls
    "age",
    "sex",
    "race",
    "year",
    "region"
]
